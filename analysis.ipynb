# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv("8. Netflix Dataset.csv")
# data.head()

# %%
# remove duplictes
data[data.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
data.drop_duplicates(inplace=True)
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %%
data.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# House of Cards... show id and director of the show
hoc=data[data["Title"].isin(["House of Cards"])]
hoc
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data[data["Title"].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
data[data["Director"].isin(['Robert Luketic'])]
# Out:
#      Show_Id Category           Title        Director  \
# 4         s5    Movie              21  Robert Luketic
# 3390   s3391    Movie         Killers  Robert Luketic
# 4202   s4203    Movie  Monster-in-Law  Robert Luketic
# 6958   s6957    Movie  The Ugly Truth  Robert Luketic
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 3390  Katherine Heigl, Ashton Kutcher, Tom Selleck, ...
# 4202  Jennifer Lopez, Jane Fonda, Michael Vartan, Wa...
# 6958  Katherine Heigl, Gerard Butler, Eric Winter, J...
#
#                      Country     Release_Date Rating Duration  \
# 4              United States  January 1, 2020  PG-13  123 min
# 3390           United States  January 1, 2021  PG-13  100 min
# 4202  United States, Germany  January 1, 2020  PG-13  101 min
# 6958           United States   April 25, 2019      R   96 min
#
#                                                Type  \
# ...

# %%
# In which year highest number of tv shows & movies were released?....Bar graph
data.dtypes
data["Date_N"]=pd.to_datetime(data['Release_Date'], format='mixed')
data.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
data.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date            object
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Date_N          datetime64[ns]
# dtype: object

# %%
data["Date_N"].dt.year.value_counts()
# Out:
# Date_N
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
data['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Date_N'>

# %%
# Howmany movies & tv shows are in the dataset?....show bargraph
data.groupby('Category').count()
# Out:
#           Show_Id  Title  Director  Cast  Country  Release_Date  Rating  \
# Category
# Movie        5377   5377      5214  4951     5147          5377    5372
# TV Show      2410   2410       185  2118     2133          2400    2408
#
#           Duration  Type  Description  Date_N
# Category
# Movie         5377  5377         5377    5377
# TV Show       2410  2410         2410    2400

# %%
# Movies released in the year 2015
data["Year"]= data["Date_N"].dt.year
# data.head()

data[(data["Category"]== 'Movie') & (data["Year"]== 2015)].head(2)
# Out:
#     Show_Id Category                    Title       Director  \
# 128    s129    Movie                  6 Years  Hannah Fidell
# 247    s248    Movie  A Very Murray Christmas  Sofia Coppola
#
#                                                   Cast        Country  \
# 128  Taissa Farmiga, Ben Rosenfield, Lindsay Burdge...  United States
# 247  Bill Murray, Miley Cyrus, George Clooney, Chri...  United States
#
#           Release_Date Rating Duration  \
# 128  September 8, 2015  TV-MA   80 min
# 247   December 4, 2015  TV-14   57 min
#
#                                             Type  \
# 128  Dramas, Independent Movies, Romantic Movies
# 247                   Comedies, Music & Musicals
#
#                                            Description     Date_N    Year
# 128  As a volatile young couple who have been toget... 2015-09-08  2015.0
# 247  Bill Murray rounds up an all-star cast for an ... 2015-12-04  2015.0

# %%
# Title of TV shows from Australia
data[(data['Category']== 'TV Show') &(data['Country'] == "Australia")] ['Title']
# Out:
# 137                      72 Cutest Animals
# 138             72 Dangerous Animals: Asia
# 140            72 Dangerous Places to Live
# 597                         Ask the Doctor
# 621     Aunty Donna's Big Ol' House of Fun
# 624                    Aussie Gold Hunters
# 1039                          Bondi Rescue
# 1296                     Cheapest Weddings
# 1511                         Court Justice
# 1587                         Dance Academy
# 1681                            Deep Water
# 2436                                Glitch
# 2567                   H2O: Just Add Water
# 2676                       Heartbreak High
# 2754             History's Greatest Hoaxes
# 3022                         Instant Hotel
# 3088                    Izzy's Koala World
# 3316                          Kath and Kim
# 3330                              Kazoops!
# 3660                          Little Lunch
# 3772                  Love on the Spectrum
# 3820                              Lunatics
# ...

# %%
# Top 10 directors with highest numbers of Tv shows & netflix
data["Director"].value_counts().head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: count, dtype: int64

# %%
# Show all Records where "Category" is Movie and Type is Comedy or country = United Kingdom
data[(data['Category']=='Movie') & (data["Type"]=="Comedies") | (data["Country"]== "United Kingdom")]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %%
# Howmany Movies/ Showd did Tom Cruise act?
# data[data["Cast"]== "Tom Cruise"]

# data[data["Cast"].str.contains("Tom Cruise")]

            # Remove Missing values
new_data=data.dropna()
new_data[new_data["Cast"].str.contains("Tom Cruise")]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %%
#  Unique Ratings

# Number of unique Ratings
data.Rating.nunique()   #data["Rating"].nunique()


data.Rating.unique()    #data["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
# How many movies Got rating "TV 14" in Canada?
data[(data["Country"]=="Canada") & (data["Rating"]=="TV-14") &(data["Category"]== "Movie")].Title.count()
# Out:
# 11

# %%
#  Howmany Movies got rating "R" after 2018
data[(data["Rating"]== "R") & (data["Year"]>2018) & (data["Category"]=="Movie")] ['Title'].count()
# Out:
# 449

# %%
# Maximum duration of a movie/ show on Netflix
# data.Duration.unique()
data['Duration'].dtypes
#  we need to organize this data.
# split the Duration to minutes column and unit column
# Out:
# dtype('O')

# %%
# split duration to minutes & units
data[['minutes','Units']]= data["Duration"].str.split(' ', expand=True)
data.head()

data.minutes.max()
# Out:
# '99'

# %%
# Which country has highest number of Tv shows?

tv_shows=data[(data["Category"]=="TV Show")]
tv_shows.Country.value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %%
#  WHich country has the highest number of Movies?
movies=data[(data["Category"]=="Movie")]
movies.Country.value_counts().head(1)
# Out:
# Country
# United States    1850
# Name: count, dtype: int64

# %%
# Find all instances where:

# Category is Movie and Type is Drama

data[(data["Category"]=="Movie") & (data["Type"]=="Dramas")].head()
# Out:
#     Show_Id Category                       Title        Director  \
# 4        s5    Movie                          21  Robert Luketic
# 7        s8    Movie                         187  Kevin Reynolds
# 170    s171    Movie                A Family Man   Mark Williams
# 232    s233    Movie  A Stoning in Fulham County   Larry Elikann
# 295    s296    Movie          Across Grace Alley   Ralph Macchio
#
#                                                   Cast                Country  \
# 4    Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...          United States
# 7    Samuel L. Jackson, John Heard, Kelly Rowan, Cl...          United States
# 170  Gerard Butler, Gretchen Mol, Alison Brie, Will...  Canada, United States
# 232  Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...          United States
# 295  Ben Hyland, Marsha Mason, Karina Smirnoff, Col...          United States
#
#           Release_Date Rating Duration    Type  \
# 4      January 1, 2020  PG-13  123 min  Dramas
# ...

# %%
# Category is TV show and Type is "Kids TV"
data[(data["Category"]=="TV Show") & (data["Type"]=="Kids' TV")]
# Out:
#      Show_Id Category              Title             Director  \
# 111     s112  TV Show            44 Cats                  NaN
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks                  NaN
# 598     s599  TV Show  Ask the StoryBots                  NaN
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7668   s7667  TV Show      World of Winx       Iginio Straffi
# 7717   s7716  TV Show               Yoko                  NaN
# 7719   s7718  TV Show                YOM                  NaN
# 7758   s7757  TV Show                 Z4                  NaN
# 7761   s7760  TV Show          Zak Storm                  NaN
#
#                                                    Cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...

# %%
data[(data["Category"]=="Movie") & (data["Type"]=="Dramas")| (data["Category"]=="TV Show") & (data["Type"]=="Kids' TV")]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
